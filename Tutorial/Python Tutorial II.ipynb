# %% [markdown]
# # Python Tutorial II
#
# In today's tutorial we'll learn how to build our own python modules and classes.  We'll start with modules:
#
# ## Modules
#
# ### When to use:
# * Your script gets very long and you want to have easier maintenance.
# * You want to reuse a function in several programs or scripts without copy/paste.
# * Performance reasons.
#
# ### What is it?
# * A file containing Python definitions and statements.
# * The file name is the module name with the suffix .py appended.
# * Within a module, the module's name is available as the valuable of the global variable *__name__*.
#
# Let's look at an example:

# %%
# module difference.py
def for_diff(function,x=0,h=.1):
    deriv=(function(x+h)-function(x))/h
    return deriv

def back_diff(function,x=0,h=.1):
    deriv=(function(x)-function(x-h))/h
    return deriv

def cent_diff(function,x=0,h=.1):
    deriv=(function(x+h)-function(x-h))/(2*h)
    return derive

# %% [markdown]
# We **import** modules just like we import libraries like numpy, math, and scipy

# %%
# %matplotlib inline   
import differences as diff
import matplotlib.pyplot as plt
import numpy as np

def myfun(x=0):
    import numpy as np
    return np.exp(-x**2)*np.sin(np.pi*x)

def myder(x=0):
    from math import sin,exp,pi
    temp=np.exp(-x**2)
    return temp*(pi*np.cos(np.pi*x)-2*x*np.sin(np.pi*x))
    
X=np.linspace(0,1,100)
dX=diff.for_diff(myfun,X,.01)
abs_err=np.abs(dX-myder(X))

plt.plot(X,abs_err)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Where does the module file need to go?
#
# Say you are trying to **import spam**.
#
# When imported, the interpreter searches for spam in(in order):
# 1. A built-in module with that name.
# 2. *spam.py* in a list of directories given by the variable *sys.path*.
#     1. The directory containing the input script (or the current directory when no file is specified).
#     2. PYTHONPATH (a list of directory names, syntax as shell variable PATH).
#     3. The installation-dependent default.
#
# ## Generaliztions of Modules: Packages
#
# Packages are modules with a directory structure.  Some of the modules with the dot.dot reference (e.g. matplotlib.pyplot.plot).  If you want to develop a well-comparmentalized package you can look at online help.

# %% [markdown]
# ## Classes
#
# Classes are a basic feature of object-oriented programming.  They are a little more complex than the *struct* features in Matlab.

# %%
class myClass:
    #Class attributes are variables that are shared by all objects of this class
    teacher='Varis Carey'
    off_hours='MW 1-2 TR 12:30-1:30'
    #instance variables are variables particular to an instance of the class and are
    #set in the CONSTRUCTOR
    def __init__(self,name,room):
        self.name=name
        self.room=room
        self.students=[] #empty student list
    
    #We can have other function within myclass-here is a METHOD to add_students
    def add_student(self,name):
        self.students.append(name)

c=myClass('M5660','M4017')
print c.name
c.add_student('Michael')
c.add_student('Megan')
print c.students
# Out:
# M5660
# ['Michael', 'Megan']

# %% [markdown]
# Let's look at an example where we encounter another example of classical object oriented programming, **Inheritance**.
#
# There's a file in the Tutuorial II directory that has the *solvers* module which contains classes used in this example.

# %%
class Solver:
    
    def __init__(self,function,start=0,tolerance=1E-8,maxiter=20):
        self.fn=function
        self.guess=start
        self.tolerance=tolerance
        self.maxiter=20
        self.iteration=0  #iteration counter
        self.root=None
    
    def state(self):
        print 'Iterate=',self.guess
        print 'Residual=',abs(self.fn(self.guess))
        print 'Iteration=',self.iteration
        if self.root!=None:
            print 'Root=',self.root

class BracketSolver(Solver):
    def __init__(self,function,guess=0,tolerance=1E-8,maxiter=20,left=-1,right=1):
            Solver.__init__(self,function,guess,tolerance,maxiter)
            self.left=left
            self.right=right
            self.lval=self.fn(left)
            self.rval=self.fn(right)
            if self.lval*self.rval > 0:
                print 'Warning: No Root guarantee',self.fn(left),self.fn(right)
            if self.left >= self.right:
                print 'Warning, Invalid Interval'
            
    def solve(self,type='bisection'):
            self.iteration+=1
            while self.iteration < self.maxiter:
                if type=='bisection':
                    self.guess=.5*(self.left+self.right) #bisect bracket
                    test=self.fn(self.guess)
                    if abs(test)<self.tolerance:  #we found a root
                        self.root=self.guess
                        return 
                    else:   #iterate
                        if self.lval*test < 0:
                            self.rval=test
                            self.right=self.guess
                            self.iteration+=1
                        else:
                            self.lval=test
                            self.left=self.guess
                            self.iteration+=1

def myfun(x):
    from math import cos
    return cos(x)-x

g=BracketSolver(myfun)
g.state()
g.solve()
g.state()
h=BracketSolver(myfun,left=g.left,right=g.right)
h.state()
h.solve()
h.state()
# Out:
# Iterate= 0
# Residual= 1.0
# Iteration= 0
# Iterate= 0.739086151123
# Residual= 1.7035832659e-06
# Iteration= 20
# Iterate= 0
# Residual= 1.0
# Iteration= 0
# Iterate= 0.739085137844
# Residual= 7.7470245774e-09
# Iteration= 6
# Root= -7.7470245774e-09

# %% [markdown]
# The inherited class (or subclass) can override methods(think functions) and attributes in the base class.

# %%
class Solver:
    
    def __init__(self,function,start=0,tolerance=1E-8,maxiter=20):
        self.fn=function
        self.guess=start
        self.tolerance=tolerance
        self.maxiter=20
        self.iteration=0  #iteration counter
        self.root=None
    
    def state(self):
        print 'Iterate=',self.guess
        print 'Residual=',abs(self.fn(self.guess))
        print 'Iteration=',self.iteration
        if self.root!=None:
            print 'Root=',self.root

class BracketSolver(Solver):
    def __init__(self,function,guess=0,tolerance=1E-8,maxiter=20,left=-1,right=1):
            Solver.__init__(self,function,guess,tolerance,maxiter)
            self.left=left
            self.right=right
            self.lval=self.fn(left)
            self.rval=self.fn(right)
            if self.lval*self.rval > 0:
                print 'Warning: No Root guarantee',self.fn(left),self.fn(right)
            if self.left >= self.right:
                print 'Warning, Invalid Interval'
            
    def solve(self,type='bisection'):
            self.iteration+=1
            while self.iteration < self.maxiter:
                if type=='bisection':
                    self.guess=.5*(self.left+self.right) #bisect bracket
                    test=self.fn(self.guess)
                    if abs(test)<self.tolerance:  #we found a root
                        self.root=self.guess
                        return 
                    else:   #iterate
                        if self.lval*test < 0:
                            self.rval=test
                            self.right=self.guess
                            self.iteration+=1
                        else:
                            self.lval=test
                            self.left=self.guess
                            self.iteration+=1
    def state(self):
        print 'Interval=[',self.left,',',self.right,']'
        #now call Solver's state function but you must call it directly!
        Solver.state(self)
    

def myfun(x):
    from math import cos
    return cos(x)-x

g=BracketSolver(myfun)
g.state()
g.solve()
g.state()
h=BracketSolver(myfun,left=g.left,right=g.right)
h.state()
h.solve()
h.state()
# Out:
# Interval=[ -1 , 1 ]
# Iterate= 0
# Residual= 1.0
# Iteration= 0
# Interval=[ 0.739082336426 , 0.739086151123 ]
# Iterate= 0.739086151123
# Residual= 1.7035832659e-06
# Iteration= 20
# Interval=[ 0.739082336426 , 0.739086151123 ]
# Iterate= 0
# Residual= 1.0
# Iteration= 0
# Interval=[ 0.739085078239 , 0.739085197449 ]
# Iterate= 0.739085137844
# Residual= 7.7470245774e-09
# Iteration= 6
# Root= 0.739085137844

# %% [markdown]
# # Basics of Profiling:
#
# ## Timeit module
#
# We saw an example of using the  *timeit* module  to test basic arithmetic operations in lecture
# .  Let's write two easy functions to test "vectorizing" code.

# %%
def dotprod(vec1,vec2):
    
    sum=0
    for x in xrange(1000):
        sum+=vec1[x]*vec2[x]
    return sum

def vecdotprod(vec1,vec2):
    sum=np.dot(vec1,vec2)
    return sum

import timeit
print(timeit.timeit("dotprod(vec1,vec2)", setup="from __main__ import dotprod;import numpy as np;vec1=np.random.rand(1000);vec2=np.random.rand(1000)",number=1000))
print(timeit.timeit("vecdotprod(vec1,vec2)", setup="from __main__ import vecdotprod;import numpy as np;vec1=np.random.rand(1000);vec2=np.random.rand(1000)",number=1000))
# Out:
# 0.438583850861
# 0.00343799591064

# %% [markdown]
# Python has its own profile module, *cprofile* or *profile*.  cProfile.run will execute a profile of a function(or a script), while runctx allows you to do more complicated passing
# arguments.

# %%
import cProfile
v1=np.random.rand(1000)
v2=np.random.rand(1000)

cProfile.runctx('dotprod(v1,v2)',globals(),locals())
cProfile.runctx('vecdotprod(v1,v2)',globals(),locals())
# Out:
#          3 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-38-6855f4ebdd86>:2(dotprod)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
#          4 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-38-6855f4ebdd86>:9(vecdotprod)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {numpy.core.multiarray.dot}

# %% [markdown]
# For finer-grain control, there is the Profile class, which has various bells and whistles, such as Profile.enable() and Profile.disable(), which turns on and turns off profiling in various pieces of code.  You can use the pstats module to process the data collected by profile.
#
# Let's look at an example using the *Wilk_roots.py* demo we saw recently.

# %%
import numpy as np
from sympy import Symbol
from sympy.polys.polytools import   poly_from_expr
import matplotlib.pyplot as plt
import cProfile,pstats

pr=cProfile.Profile()

pr.enable()
x = Symbol('x')
W = 1
for i in range(1, 21):
    W = W * (x-i)

P,d = poly_from_expr(W.expand())
p = P.all_coeffs()
pr.disable()
print p
x = np.arange(1, 21)
plt.scatter(x,np.zeros(20),c=x)

pr.enable()
for l in xrange(0,100):
    ptilde=p*(1+1E-11*np.random.rand(21))

    roots=np.roots(ptilde)

    X = roots.real 
    Y = roots.imag 
    plt.scatter(X,Y, c=x, s=.5)

roots=np.roots(p)
pr.disable()
print roots

plt.grid()    
plt.show()
pr.print_stats()
# Out:
# [1, -210, 20615, -1256850, 53327946, -1672280820, 40171771630, -756111184500, 11310276995381, -135585182899530, 1307535010540395, -10142299865511450, 63030812099294896, -311333643161390640, 1206647803780373360, -3599979517947607200, 8037811822645051776, -12870931245150988800, 13803759753640704000, -8752948036761600000, 2432902008176640000]
# [ 19.99985372  19.00148315  17.99285196  17.02058865  15.95568255
#   15.06447327  13.92449534  13.06779554  11.9554266   11.02467745
#    9.9901793    9.00309742   7.9992907    7.00011612   5.99998749
#    5.00000076   3.99999999   3.           2.           1.        ]
#          473025 function calls (456985 primitive calls) in 0.585 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-43-41b58e1326ee>:10(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-43-41b58e1326ee>:11(<module>)
#         1    0.000    0.000    0.063    0.063 <ipython-input-43-41b58e1326ee>:12(<module>)
#         1    0.000    0.000    0.089    0.089 <ipython-input-43-41b58e1326ee>:15(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-43-41b58e1326ee>:16(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-43-41b58e1326ee>:17(<module>)
#         1    0.007    0.007    0.431    0.431 <ipython-input-43-41b58e1326ee>:23(<module>)
#         1    0.000    0.000    0.001    0.001 <ipython-input-43-41b58e1326ee>:32(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-43-41b58e1326ee>:33(<module>)
#      2700    0.004    0.000    0.005    0.000 UserDict.py:4(__init__)
#       100    0.001    0.000    0.283    0.003 __init__.py:1733(inner)
#      1700    0.002    0.000    0.002    0.000 __init__.py:888(__getitem__)
#       100    0.005    0.000    0.281    0.003 _axes.py:3710(scatter)
#       100    0.000    0.000    0.000    0.000 _base.py:1134(ishold)
#       100    0.000    0.000    0.000    0.000 _base.py:1138(hold)
#       100    0.001    0.000    0.001    0.000 _base.py:1608(_sci)
#       100    0.002    0.000    0.093    0.001 _base.py:1662(add_collection)
#       100    0.001    0.000    0.006    0.000 _base.py:1864(update_datalim)
#       200    0.001    0.000    0.006    0.000 _base.py:1901(_process_unit_info)
#       100    0.006    0.000    0.070    0.001 _base.py:2130(autoscale_view)
#       100    0.000    0.000    0.000    0.000 _base.py:2665(xaxis_inverted)
#       100    0.000    0.000    0.001    0.000 _base.py:2670(get_xbound)
#       100    0.000    0.000    0.041    0.000 _base.py:2683(set_xbound)
#       300    0.001    0.000    0.001    0.000 _base.py:2710(get_xlim)
#       100    0.001    0.000    0.039    0.000 _base.py:2716(set_xlim)
#       100    0.000    0.000    0.000    0.000 _base.py:2925(yaxis_inverted)
#       100    0.000    0.000    0.001    0.000 _base.py:2930(get_ybound)
#       100    0.000    0.000    0.010    0.000 _base.py:2941(set_ybound)
#       300    0.001    0.000    0.001    0.000 _base.py:2968(get_ylim)
#       100    0.001    0.000    0.008    0.000 _base.py:2974(set_ylim)
#       100    0.000    0.000    0.001    0.000 _base.py:859(_set_artist_props)
#       100    0.000    0.000    0.001    0.000 _methods.py:25(_amax)
#       100    0.000    0.000    0.001    0.000 _methods.py:28(_amin)
#       802    0.001    0.000    0.005    0.000 _methods.py:40(_all)
#       200    0.000    0.000    0.000    0.000 _pylab_helpers.py:119(get_active)
#      2713    0.001    0.000    0.001    0.000 _weakrefset.py:16(__init__)
#      2713    0.002    0.000    0.003    0.000 _weakrefset.py:20(__enter__)
#      2713    0.003    0.000    0.005    0.000 _weakrefset.py:26(__exit__)
#       131    0.000    0.000    0.004    0.000 add.py:16(_addsort)
#        76    0.000    0.000    0.000    0.000 add.py:335(as_coeff_Add)
#        19    0.000    0.000    0.000    0.000 add.py:450(<lambda>)
#        57    0.000    0.000    0.000    0.000 add.py:451(<genexpr>)
#        19    0.000    0.000    0.000    0.000 add.py:452(<lambda>)
#        57    0.000    0.000    0.000    0.000 add.py:453(<genexpr>)
#        19    0.000    0.000    0.000    0.000 add.py:454(<lambda>)
#        38    0.000    0.000    0.000    0.000 add.py:455(<genexpr>)
#        19    0.000    0.000    0.000    0.000 add.py:456(<lambda>)
#        57    0.000    0.000    0.000    0.000 add.py:457(<genexpr>)
#        19    0.000    0.000    0.000    0.000 add.py:458(<lambda>)
#        57    0.000    0.000    0.000    0.000 add.py:459(<genexpr>)
#        19    0.000    0.000    0.000    0.000 add.py:460(<lambda>)
#        57    0.000    0.000    0.000    0.000 add.py:461(<genexpr>)
#        19    0.000    0.000    0.000    0.000 add.py:462(<lambda>)
#        57    0.000    0.000    0.000    0.000 add.py:463(<genexpr>)
#        19    0.000    0.000    0.000    0.000 add.py:464(<lambda>)
#        57    0.000    0.000    0.000    0.000 add.py:465(<genexpr>)
#        19    0.000    0.000    0.000    0.000 add.py:466(<lambda>)
#        57    0.000    0.000    0.000    0.000 add.py:467(<genexpr>)
#        19    0.000    0.000    0.000    0.000 add.py:469(_eval_is_imaginary)
#        19    0.000    0.000    0.005    0.000 add.py:491(_eval_is_zero)
#        19    0.000    0.000    0.002    0.000 add.py:520(_eval_is_odd)
#        19    0.000    0.000    0.000    0.000 add.py:527(_eval_is_irrational)
#        19    0.000    0.000    0.001    0.000 add.py:540(_eval_is_positive)
#        19    0.000    0.000    0.000    0.000 add.py:594(_eval_is_nonnegative)
#        19    0.000    0.000    0.000    0.000 add.py:609(_eval_is_nonpositive)
#        19    0.000    0.000    0.008    0.000 add.py:624(_eval_is_negative)
#       131    0.003    0.000    0.024    0.000 add.py:74(flatten)
#       100    0.000    0.000    0.000    0.000 artist.py:1002(mouseover)
#       500    0.001    0.000    0.004    0.000 artist.py:182(convert_xunits)
#       500    0.001    0.000    0.004    0.000 artist.py:191(convert_yunits)
#      1400    0.000    0.000    0.000    0.000 artist.py:224(axes)
#       200    0.000    0.000    0.000    0.000 artist.py:232(axes)
# 2800/2300    0.003    0.000    0.004    0.000 artist.py:256(stale)
#       900    0.001    0.000    0.002    0.000 artist.py:314(pchanged)
#       100    0.000    0.000    0.000    0.000 artist.py:322(is_transform_set)
#       100    0.000    0.000    0.000    0.000 artist.py:329(set_transform)
#       200    0.000    0.000    0.000    0.000 artist.py:341(get_transform)
#       100    0.000    0.000    0.000    0.000 artist.py:624(set_figure)
#       100    0.001    0.000    0.030    0.000 artist.py:657(set_clip_path)
#       100    0.000    0.000    0.001    0.000 artist.py:72(_stale_axes_callback)
#      2800    0.001    0.000    0.001    0.000 artist.py:724(get_animated)
#       100    0.000    0.000    0.000    0.000 artist.py:736(get_clip_path)
#       100    0.000    0.000    0.000    0.000 artist.py:810(set_alpha)
#       200    0.001    0.000    0.005    0.000 artist.py:841(update)
#       100    0.001    0.000    0.001    0.000 artist.py:86(__init__)
#       100    0.000    0.000    0.000    0.000 artist.py:864(get_label)
#       200    0.000    0.000    0.001    0.000 artist.py:870(set_label)
#       100    0.000    0.000    0.001    0.000 artist.py:889(set_zorder)
#       184    0.000    0.000    0.010    0.000 assumptions.py:212(__init__)
#       184    0.000    0.000    0.010    0.000 assumptions.py:223(copy)
#       117    0.000    0.000    0.000    0.000 assumptions.py:226(generator)
# 4519/1242    0.004    0.000    0.072    0.000 assumptions.py:239(getit)
#  1534/150    0.012    0.000    0.062    0.000 assumptions.py:251(_ask)
#       200    0.000    0.000    0.000    0.000 axis.py:1271(get_major_locator)
#       300    0.001    0.000    0.005    0.000 axis.py:1376(update_units)
#       300    0.000    0.000    0.000    0.000 axis.py:1432(have_units)
#       600    0.001    0.000    0.006    0.000 axis.py:1435(convert_units)
#       100    0.000    0.000    0.000    0.000 axis.py:1935(get_minpos)
#       100    0.000    0.000    0.000    0.000 axis.py:2266(get_minpos)
#       200    0.000    0.000    0.001    0.000 axis.py:699(limit_range_for_scale)
# 5375/4783    0.002    0.000    0.003    0.000 basic.py:102(__hash__)
#      2017    0.000    0.000    0.000    0.000 basic.py:111(_hashable_content)
#  1627/831    0.009    0.000    0.017    0.000 basic.py:151(compare)
#       641    0.002    0.000    0.003    0.000 basic.py:278(__eq__)
#       465    0.000    0.000    0.001    0.000 basic.py:330(__ne__)
#         1    0.000    0.000    0.000    0.000 basic.py:394(__str__)
#       205    0.000    0.000    0.000    0.000 basic.py:610(func)
#      5435    0.001    0.000    0.001    0.000 basic.py:636(args)
#      5101    0.005    0.000    0.006    0.000 basic.py:77(__new__)
#        57    0.000    0.000    0.000    0.000 boolalg.py:188(__nonzero__)
#        92    0.000    0.000    0.000    0.000 boolalg.py:193(__hash__)
#        12    0.000    0.000    0.000    0.000 boolalg.py:242(__nonzero__)
#        23    0.000    0.000    0.000    0.000 boolalg.py:273(<lambda>)
#       400    0.000    0.000    0.000    0.000 cbook.py:1681(clean)
#       400    0.001    0.000    0.002    0.000 cbook.py:1757(get_siblings)
#       100    0.004    0.000    0.014    0.000 cbook.py:1802(delete_masked_points)
#       100    0.001    0.000    0.001    0.000 cbook.py:2547(get_label)
#       100    0.000    0.000    0.000    0.000 cbook.py:493(__init__)
#       500    0.000    0.000    0.000    0.000 cbook.py:555(process)
#      1800    0.002    0.000    0.003    0.000 cbook.py:687(iterable)
#      1000    0.009    0.000    0.009    0.000 cbook.py:696(is_string_like)
#       300    0.001    0.000    0.001    0.000 cm.py:138(get_cmap)
#       100    0.001    0.000    0.002    0.000 cm.py:176(__init__)
#       100    0.000    0.000    0.000    0.000 cm.py:265(set_array)
#       100    0.000    0.000    0.001    0.000 cm.py:300(set_cmap)
#       100    0.000    0.000    0.000    0.000 cm.py:310(set_norm)
#       100    0.000    0.000    0.023    0.000 cm.py:327(autoscale_None)
#       300    0.001    0.000    0.001    0.000 cm.py:354(changed)
#         9    0.000    0.000    0.001    0.000 codeop.py:132(__call__)
#       100    0.000    0.000    0.000    0.000 collections.py:142(_get_value)
#       100    0.000    0.000    0.000    0.000 collections.py:157(_get_bool)
#       100    0.000    0.000    0.000    0.000 collections.py:173(get_transforms)
#       100    0.000    0.000    0.000    0.000 collections.py:176(get_offset_transform)
#       100    0.002    0.000    0.053    0.001 collections.py:183(get_datalim)
#       100    0.000    0.000    0.000    0.000 collections.py:330(set_pickradius)
#       100    0.000    0.000    0.000    0.000 collections.py:373(set_urls)
#       100    0.000    0.000    0.000    0.000 collections.py:383(set_hatch)
#       100    0.000    0.000    0.000    0.000 collections.py:446(set_offset_position)
#       100    0.000    0.000    0.001    0.000 collections.py:470(set_linewidth)
#       100    0.000    0.000    0.001    0.000 collections.py:491(set_linestyle)
#       100    0.000    0.000    0.001    0.000 collections.py:563(set_antialiased)
#       100    0.001    0.000    0.002    0.000 collections.py:592(set_facecolor)
#       100    0.001    0.000    0.003    0.000 collections.py:631(set_edgecolor)
#       100    0.001    0.000    0.003    0.000 collections.py:667(set_alpha)
#       100    0.002    0.000    0.002    0.000 collections.py:787(set_sizes)
#       100    0.001    0.000    0.020    0.000 collections.py:822(__init__)
#       100    0.000    0.000    0.000    0.000 collections.py:836(set_paths)
#       100    0.000    0.000    0.000    0.000 collections.py:840(get_paths)
#       100    0.002    0.000    0.017    0.000 collections.py:91(__init__)
#       400    0.000    0.000    0.000    0.000 colors.py:265(to_rgb)
#       400    0.001    0.000    0.002    0.000 colors.py:334(to_rgba)
#       400    0.001    0.000    0.004    0.000 colors.py:378(to_rgba_array)
#       200    0.000    0.000    0.000    0.000 colors.py:864(__init__)
#       100    0.001    0.000    0.023    0.000 colors.py:975(autoscale_None)
#        92    0.001    0.000    0.001    0.000 compatibility.py:591(ordered)
#        23    0.000    0.000    0.000    0.000 complexes.py:144(eval)
#        23    0.000    0.000    0.000    0.000 complexes.py:52(eval)
#         1    0.000    0.000    0.000    0.000 constructor.py:14(_construct_simple)
#         1    0.000    0.000    0.000    0.000 constructor.py:221(construct_domain)
#         1    0.000    0.000    0.000    0.000 containers.py:35(__new__)
#         1    0.000    0.000    0.000    0.000 containers.py:52(__iter__)
#      1627    0.001    0.000    0.003    0.000 core.py:101(__gt__)
#       200    0.000    0.000    0.000    0.000 core.py:1753(_check_mask_axis)
#       200    0.000    0.000    0.002    0.000 core.py:237(_recursive_extremum_fill_value)
#       100    0.000    0.000    0.001    0.000 core.py:248(minimum_fill_value)
#       300    0.003    0.000    0.015    0.000 core.py:2707(__new__)
#       700    0.005    0.000    0.010    0.000 core.py:2841(_update_from)
#       600    0.006    0.000    0.017    0.000 core.py:2867(__array_finalize__)
#       100    0.000    0.000    0.001    0.000 core.py:311(maximum_fill_value)
#      1600    0.002    0.000    0.002    0.000 core.py:3267(__setattr__)
#       300    0.000    0.000    0.000    0.000 core.py:3487(_get_data)
#       200    0.000    0.000    0.001    0.000 core.py:3579(filled)
#       100    0.001    0.000    0.004    0.000 core.py:4294(ravel)
#       100    0.001    0.000    0.006    0.000 core.py:5434(min)
#       100    0.001    0.000    0.005    0.000 core.py:5533(max)
#       100    0.000    0.000    0.000    0.000 core.py:559(filled)
#      2000    0.001    0.000    0.001    0.000 core.py:6042(isMaskedArray)
#       100    0.001    0.000    0.012    0.000 core.py:6293(min)
#       100    0.001    0.000    0.010    0.000 core.py:6303(max)
#       400    0.001    0.000    0.011    0.000 core.py:6358(__call__)
#      3263    0.003    0.000    0.004    0.000 core.py:73(__cmp__)
#       200    0.001    0.000    0.010    0.000 core.py:7581(asanyarray)
#      1627    0.001    0.000    0.003    0.000 core.py:96(__lt__)
#     87/49    0.000    0.000    0.062    0.001 decorators.py:108(binary_op_wrapper)
# 4288/2149    0.006    0.000    0.154    0.000 decorators.py:70(__sympifyit_wrapper)
#         1    0.000    0.000    0.000    0.000 densebasic.py:255(dup_strip)
#         1    0.000    0.000    0.000    0.000 densebasic.py:698(dmp_zero_p)
#         1    0.000    0.000    0.000    0.000 densebasic.py:920(dup_from_dict)
#         1    0.000    0.000    0.000    0.000 densebasic.py:978(dmp_from_dict)
#        21    0.000    0.000    0.000    0.000 domain.py:148(of_type)
#        21    0.000    0.000    0.000    0.000 domain.py:66(tp)
#         2    0.000    0.000    0.000    0.000 domain.py:77(convert_from)
#        21    0.000    0.000    0.000    0.000 domain.py:94(convert)
#        22    0.000    0.000    0.000    0.000 evalf.py:1236(<lambda>)
#        23    0.000    0.000    0.000    0.000 evalf.py:1237(<lambda>)
#         1    0.000    0.000    0.000    0.000 evalf.py:1243(<lambda>)
#        46    0.000    0.000    0.001    0.000 evalf.py:1274(evalf)
#        46    0.000    0.000    0.001    0.000 evalf.py:1329(evalf)
#        29    0.000    0.000    0.002    0.000 expr.py:128(__sub__)
#     57/19    0.000    0.000    0.060    0.003 expr.py:138(__mul__)
#         1    0.000    0.000    0.000    0.000 expr.py:143(__rmul__)
#        23    0.000    0.000    0.006    0.000 expr.py:1638(as_real_imag)
#       356    0.000    0.000    0.000    0.000 expr.py:1704(as_base_exp)
#       104    0.000    0.000    0.000    0.000 expr.py:2829(as_coeff_Mul)
#   1616/18    0.005    0.000    0.086    0.005 expr.py:2879(_expand_hint)
#         2    0.000    0.000    0.086    0.043 expr.py:2909(expand)
#        12    0.000    0.000    0.000    0.000 expr.py:2952(_expand_hint_key)
#   156/124    0.000    0.000    0.001    0.000 expr.py:322(is_number)
#   427/345    0.000    0.000    0.000    0.000 expr.py:346(<genexpr>)
#         1    0.000    0.000    0.000    0.000 expr.py:689(_eval_is_positive)
#        24    0.000    0.000    0.010    0.000 expr.py:719(_eval_is_negative)
#        19    0.000    0.000    0.000    0.000 expr.py:787(_eval_power)
#        20    0.000    0.000    0.000    0.000 exprtools.py:206(decompose_power)
#        38    0.000    0.000    0.000    0.000 exprtools.py:31(_monotonic_sign)
#      8029    0.006    0.000    0.006    0.000 facts.py:486(_tell)
#       406    0.010    0.000    0.021    0.000 facts.py:503(deduce_all_facts)
#     10067    0.004    0.000    0.004    0.000 facts.py:537(<genexpr>)
#       200    0.000    0.000    0.001    0.000 figure.py:1317(gca)
#       200    0.000    0.000    0.000    0.000 figure.py:139(current_key_axes)
#       400    0.000    0.000    0.001    0.000 figure.py:54(_stale_figure_callback)
#       101    0.000    0.000    0.001    0.000 fromnumeric.py:1383(ravel)
#       101    0.000    0.000    0.002    0.000 fromnumeric.py:1490(nonzero)
#       101    0.000    0.000    0.001    0.000 fromnumeric.py:1973(all)
#       200    0.000    0.000    0.000    0.000 fromnumeric.py:2659(size)
#       200    0.000    0.000    0.001    0.000 fromnumeric.py:56(take)
#        46    0.000    0.000    0.003    0.000 function.py:140(nargs)
#        46    0.000    0.000    0.001    0.000 function.py:194(__new__)
#        46    0.000    0.000    0.006    0.000 function.py:362(__new__)
#        19    0.000    0.000    0.000    0.000 function.py:62(_coeff_isneg)
#       688    0.000    0.000    0.000    0.000 functools.py:84(__init__)
#       831    0.001    0.000    0.018    0.000 functools.py:86(__lt__)
#         9    0.000    0.000    0.000    0.000 hooks.py:127(__call__)
#         9    0.000    0.000    0.000    0.000 hooks.py:192(pre_run_code_hook)
#         9    0.000    0.000    0.000    0.000 interactiveshell.py:1087(user_global_ns)
#         9    0.000    0.000    0.584    0.065 interactiveshell.py:2855(run_code)
#         9    0.000    0.000    0.000    0.000 ipstruct.py:125(__getattr__)
#      4019    0.003    0.000    0.006    0.000 libintmath.py:83(python_bitcount)
#      8535    0.010    0.000    0.010    0.000 libmpf.py:153(_normalize)
#      2100    0.005    0.000    0.005    0.000 libmpf.py:208(_normalize1)
#      4289    0.007    0.000    0.020    0.000 libmpf.py:291(from_man_exp)
#      2189    0.001    0.000    0.012    0.000 libmpf.py:330(from_int)
#      2100    0.004    0.000    0.014    0.000 libmpf.py:410(from_float)
#      2121    0.002    0.000    0.002    0.000 libmpf.py:429(to_float)
#        23    0.000    0.000    0.000    0.000 libmpf.py:511(mpf_eq)
#        23    0.000    0.000    0.000    0.000 libmpf.py:548(mpf_cmp)
#        23    0.000    0.000    0.000    0.000 libmpf.py:600(mpf_lt)
#      2146    0.003    0.000    0.004    0.000 libmpf.py:64(dps_to_prec)
#        23    0.000    0.000    0.000    0.000 libmpf.py:666(mpf_sign)
#      2100    0.004    0.000    0.009    0.000 libmpf.py:858(python_mpf_mul)
#       201    0.000    0.000    0.000    0.000 linalg.py:101(get_linalg_error_extobj)
#       201    0.000    0.000    0.001    0.000 linalg.py:106(_makearray)
#       503    0.000    0.000    0.000    0.000 linalg.py:111(isComplexType)
#       202    0.000    0.000    0.000    0.000 linalg.py:124(_realType)
#       100    0.000    0.000    0.000    0.000 linalg.py:127(_complexType)
#       201    0.001    0.000    0.001    0.000 linalg.py:139(_commonType)
#       201    0.000    0.000    0.000    0.000 linalg.py:198(_assertRankAtLeast2)
#       201    0.000    0.000    0.001    0.000 linalg.py:209(_assertNdSquareness)
#       101    0.000    0.000    0.001    0.000 linalg.py:214(_assertFinite)
#       101    0.000    0.000    0.000    0.000 linalg.py:219(_assertNoEmpty2d)
#       100    0.003    0.000    0.005    0.000 linalg.py:458(inv)
#       101    0.015    0.000    0.019    0.000 linalg.py:832(eigvals)
#       366    0.001    0.000    0.002    0.000 logic.py:40(_fuzzy_group)
#         1    0.000    0.000    0.000    0.000 logic.py:89(fuzzy_bool)
#       100    0.000    0.000    0.023    0.000 markers.py:148(__init__)
#       200    0.001    0.000    0.021    0.000 markers.py:184(_recache)
#       100    0.000    0.000    0.000    0.000 markers.py:202(is_filled)
#       400    0.000    0.000    0.000    0.000 markers.py:205(get_fillstyle)
#       100    0.000    0.000    0.010    0.000 markers.py:208(set_fillstyle)
#       100    0.001    0.000    0.013    0.000 markers.py:233(set_marker)
#       100    0.000    0.000    0.000    0.000 markers.py:257(get_path)
#       100    0.000    0.000    0.001    0.000 markers.py:260(get_transform)
#       200    0.001    0.000    0.001    0.000 markers.py:346(_half_fill)
#       200    0.002    0.000    0.013    0.000 markers.py:351(_set_circle)
#        39    0.000    0.000    0.000    0.000 mul.py:1007(<lambda>)
#        99    0.000    0.000    0.000    0.000 mul.py:1008(<genexpr>)
#        39    0.000    0.000    0.000    0.000 mul.py:1009(<lambda>)
#       270    0.000    0.000    0.000    0.000 mul.py:1010(<genexpr>)
#        39    0.000    0.000    0.000    0.000 mul.py:1011(<lambda>)
#        99    0.000    0.000    0.000    0.000 mul.py:1012(<genexpr>)
#        39    0.000    0.000    0.001    0.000 mul.py:1014(_eval_is_infinite)
#       270    0.000    0.000    0.001    0.000 mul.py:1015(<genexpr>)
#        39    0.000    0.000    0.000    0.000 mul.py:1022(_eval_is_rational)
#        99    0.000    0.000    0.000    0.000 mul.py:1023(<genexpr>)
#        39    0.000    0.000    0.000    0.000 mul.py:1029(_eval_is_algebraic)
#        99    0.000    0.000    0.000    0.000 mul.py:1030(<genexpr>)
#        39    0.000    0.000    0.029    0.001 mul.py:1036(_eval_is_zero)
#        39    0.000    0.000    0.010    0.000 mul.py:1053(_eval_is_integer)
#        39    0.000    0.000    0.000    0.000 mul.py:1070(_eval_is_real)
#        39    0.000    0.000    0.000    0.000 mul.py:1073(_eval_real_imag)
#        39    0.000    0.000    0.001    0.000 mul.py:1105(_eval_is_imaginary)
#        39    0.000    0.000    0.001    0.000 mul.py:1112(_eval_is_hermitian)
#        39    0.000    0.000    0.001    0.000 mul.py:1115(_eval_herm_antiherm)
#        39    0.000    0.000    0.000    0.000 mul.py:1148(_eval_is_antihermitian)
#        39    0.000    0.000    0.000    0.000 mul.py:1155(_eval_is_irrational)
#        39    0.000    0.000    0.001    0.000 mul.py:1168(_eval_is_positive)
#        78    0.000    0.000    0.002    0.000 mul.py:1183(_eval_pos_neg)
#        39    0.000    0.000    0.002    0.000 mul.py:1215(_eval_is_negative)
#        39    0.000    0.000    0.004    0.000 mul.py:1220(_eval_is_odd)
#        39    0.000    0.000    0.004    0.000 mul.py:1244(_eval_is_even)
#        39    0.000    0.000    0.003    0.000 mul.py:1253(_eval_is_prime)
#       369    0.000    0.000    0.016    0.000 mul.py:30(_mulsort)
#       738    0.005    0.000    0.013    0.000 mul.py:375(_gather)
#       328    0.001    0.000    0.001    0.000 mul.py:703(as_coeff_Mul)
#      39/1    0.001    0.000    0.070    0.070 mul.py:769(_expandsums)
#        58    0.000    0.000    0.078    0.001 mul.py:788(_eval_expand_mul)
#        57    0.000    0.000    0.000    0.000 mul.py:822(<genexpr>)
#   369/368    0.012    0.000    0.116    0.000 mul.py:95(flatten)
#        46    0.000    0.000    0.001    0.000 numbers.py:1024(__eq__)
#        23    0.000    0.000    0.001    0.000 numbers.py:1084(__lt__)
#       138    0.000    0.000    0.000    0.000 numbers.py:1112(__hash__)
#      1452    0.001    0.000    0.001    0.000 numbers.py:1359(_hashable_content)
#        34    0.000    0.000    0.000    0.000 numbers.py:1362(_eval_is_positive)
#       117    0.000    0.000    0.000    0.000 numbers.py:1365(_eval_is_zero)
#         1    0.000    0.000    0.000    0.000 numbers.py:1371(__add__)
#      2100    0.003    0.000    0.045    0.000 numbers.py:1389(__mul__)
#        80    0.000    0.000    0.001    0.000 numbers.py:1488(__eq__)
#         1    0.000    0.000    0.000    0.000 numbers.py:1614(as_numer_denom)
#      2167    0.002    0.000    0.013    0.000 numbers.py:1711(_as_mpf_val)
#      1713    0.003    0.000    0.004    0.000 numbers.py:1718(__new__)
#        19    0.000    0.000    0.000    0.000 numbers.py:1753(__neg__)
#         1    0.000    0.000    0.000    0.000 numbers.py:1762(__divmod__)
#       413    0.001    0.000    0.002    0.000 numbers.py:1784(__add__)
#      3192    0.005    0.000    0.101    0.000 numbers.py:1808(__mul__)
#         1    0.000    0.000    0.000    0.000 numbers.py:1820(__mod__)
#       252    0.000    0.000    0.001    0.000 numbers.py:1834(__eq__)
#      3841    0.002    0.000    0.002    0.000 numbers.py:1880(__hash__)
#        19    0.000    0.000    0.000    0.000 numbers.py:1888(_eval_is_odd)
#        57    0.000    0.000    0.000    0.000 numbers.py:2011(as_numer_denom)
#       392    0.000    0.000    0.000    0.000 numbers.py:2229(__nonzero__)
#        10    0.000    0.000    0.000    0.000 numbers.py:2263(__neg__)
#       270    0.000    0.000    0.001    0.000 numbers.py:2549(__hash__)
#        40    0.000    0.000    0.000    0.000 numbers.py:2760(__hash__)
#        23    0.000    0.000    0.000    0.000 numbers.py:2906(_as_mpf_val)
#        63    0.000    0.000    0.000    0.000 numbers.py:2913(__hash__)
#        38    0.000    0.000    0.000    0.000 numbers.py:2916(__eq__)
#        23    0.000    0.000    0.001    0.000 numbers.py:398(_eval_evalf)
#      2100    0.002    0.000    0.015    0.000 numbers.py:401(_as_mpf_op)
#      2121    0.002    0.000    0.009    0.000 numbers.py:405(__float__)
#        38    0.000    0.000    0.000    0.000 numbers.py:421(_eval_is_finite)
#       511    0.000    0.000    0.001    0.000 numbers.py:526(__hash__)
#       753    0.000    0.000    0.000    0.000 numbers.py:546(as_coeff_Mul)
#      2100    0.011    0.000    0.036    0.000 numbers.py:739(__new__)
#      4246    0.003    0.000    0.007    0.000 numbers.py:74(mpf_norm)
#      2146    0.003    0.000    0.009    0.000 numbers.py:844(_new)
#        23    0.000    0.000    0.000    0.000 numbers.py:864(_hashable_content)
#      2100    0.001    0.000    0.004    0.000 numbers.py:879(_as_mpf_val)
#      4200    0.001    0.000    0.001    0.000 numbers.py:918(__nonzero__)
#      2100    0.005    0.000    0.039    0.000 numbers.py:940(__mul__)
#       101    0.000    0.000    0.001    0.000 numeric.py:148(ones)
#       300    0.002    0.000    0.004    0.000 numeric.py:2279(identity)
#      1701    0.001    0.000    0.004    0.000 numeric.py:414(asarray)
#      1306    0.001    0.000    0.002    0.000 numeric.py:484(asanyarray)
#       200    0.001    0.000    0.001    0.000 numerictypes.py:603(obj2sctype)
#       200    0.000    0.000    0.001    0.000 numerictypes.py:774(__getitem__)
#   562/386    0.004    0.000    0.133    0.000 operations.py:27(__new__)
#       101    0.000    0.000    0.000    0.000 operations.py:347(make_args)
#       510    0.001    0.000    0.002    0.000 operations.py:49(_from_args)
#        10    0.000    0.000    0.000    0.000 operations.py:63(_new_rawargs)
#       100    0.000    0.000    0.022    0.000 patches.py:192(get_transform)
#       100    0.001    0.000    0.019    0.000 patches.py:655(_update_patch_transform)
#       100    0.000    0.000    0.019    0.000 patches.py:671(get_patch_transform)
#       400    0.003    0.000    0.010    0.000 path.py:103(__init__)
#       400    0.002    0.000    0.006    0.000 path.py:212(_update_values)
#      2300    0.000    0.000    0.000    0.000 path.py:221(vertices)
#      2200    0.000    0.000    0.000    0.000 path.py:235(codes)
#      2100    0.000    0.000    0.000    0.000 path.py:254(simplify_threshold)
#      2100    0.000    0.000    0.000    0.000 path.py:273(should_simplify)
#       100    0.000    0.000    0.004    0.000 path.py:469(transformed)
#       200    0.000    0.000    0.000    0.000 path.py:702(unit_circle)
#       100    0.001    0.000    0.012    0.000 path.py:960(get_path_collection_extents)
#         1    0.000    0.000    0.000    0.000 polyclasses.py:1020(__nonzero__)
#         1    0.000    0.000    0.000    0.000 polyclasses.py:149(__init__)
#         1    0.000    0.000    0.000    0.000 polyclasses.py:256(from_dict)
#         1    0.000    0.000    0.000    0.000 polyclasses.py:300(all_coeffs)
#       101    0.003    0.000    0.040    0.000 polynomial.py:157(roots)
#         1    0.000    0.000    0.000    0.000 polyoptions.py:127(__init__)
#         2    0.000    0.000    0.000    0.000 polyoptions.py:139(preprocess_options)
#         1    0.000    0.000    0.000    0.000 polyoptions.py:204(clone)
#         2    0.000    0.000    0.000    0.000 polyoptions.py:216(__setattr__)
#         2    0.000    0.000    0.000    0.000 polyoptions.py:264(default)
#         1    0.000    0.000    0.000    0.000 polyoptions.py:277(default)
#         8    0.000    0.000    0.000    0.000 polyoptions.py:30(default)
#         1    0.000    0.000    0.000    0.000 polyoptions.py:333(default)
#        19    0.000    0.000    0.000    0.000 polyoptions.py:38(postprocess)
#         1    0.000    0.000    0.000    0.000 polyoptions.py:485(postprocess)
#         1    0.000    0.000    0.000    0.000 polyoptions.py:505(postprocess)
#         1    0.000    0.000    0.000    0.000 polyoptions.py:520(postprocess)
#         1    0.000    0.000    0.000    0.000 polyoptions.py:553(postprocess)
#         1    0.000    0.000    0.000    0.000 polyoptions.py:578(postprocess)
#         1    0.000    0.000    0.000    0.000 polyoptions.py:616(postprocess)
#        34    0.000    0.000    0.000    0.000 polyoptions.py:64(getter)
#        20    0.000    0.000    0.000    0.000 polyoptions.py:690(default)
#         3    0.000    0.000    0.000    0.000 polyoptions.py:725(build_options)
#         1    0.000    0.000    0.000    0.000 polytools.py:131(_from_dict)
#         1    0.000    0.000    0.008    0.008 polytools.py:4116(poly_from_expr)
#         1    0.000    0.000    0.008    0.008 polytools.py:4123(_poly_from_expr)
#         1    0.000    0.000    0.000    0.000 polytools.py:799(all_coeffs)
#         1    0.000    0.000    0.000    0.000 polytools.py:91(new)
#        40    0.000    0.000    0.002    0.000 polyutils.py:172(_not_a_coeff)
#         1    0.000    0.000    0.002    0.002 polyutils.py:227(_parallel_dict_from_expr_no_gens)
#        20    0.000    0.000    0.000    0.000 polyutils.py:236(_is_coeff)
#         1    0.000    0.000    0.002    0.002 polyutils.py:315(_dict_from_expr_no_gens)
#         1    0.000    0.000    0.003    0.003 polyutils.py:349(_dict_from_expr)
#        59    0.000    0.000    0.000    0.000 polyutils.py:354(_is_expandable_pow)
#        22    0.000    0.000    0.000    0.000 polyutils.py:364(<genexpr>)
#        57    0.000    0.000    0.000    0.000 polyutils.py:365(<genexpr>)
#        22    0.000    0.000    0.000    0.000 polyutils.py:369(<genexpr>)
#         1    0.000    0.000    0.000    0.000 polyutils.py:64(_sort_gens)
#         1    0.000    0.000    0.000    0.000 polyutils.py:76(order_key)
#         9    0.000    0.000    0.000    0.000 power.py:1009(_eval_is_rational)
#         9    0.000    0.000    0.000    0.000 power.py:1027(_eval_is_algebraic)
#        19    0.000    0.000    0.000    0.000 power.py:164(__new__)
#       311    0.000    0.000    0.000    0.000 power.py:211(base)
#       280    0.000    0.000    0.000    0.000 power.py:215(exp)
#         9    0.000    0.000    0.000    0.000 power.py:315(_eval_is_even)
#         9    0.000    0.000    0.000    0.000 power.py:319(_eval_is_positive)
#         9    0.000    0.000    0.000    0.000 power.py:345(_eval_is_negative)
#         9    0.000    0.000    0.000    0.000 power.py:364(_eval_is_zero)
#         9    0.000    0.000    0.000    0.000 power.py:382(_eval_is_integer)
#         9    0.000    0.000    0.000    0.000 power.py:399(_eval_is_real)
#         9    0.000    0.000    0.000    0.000 power.py:454(_eval_is_complex)
#        18    0.000    0.000    0.000    0.000 power.py:455(<genexpr>)
#         9    0.000    0.000    0.001    0.000 power.py:458(_eval_is_imaginary)
#         9    0.000    0.000    0.000    0.000 power.py:496(_eval_is_odd)
#         9    0.000    0.000    0.000    0.000 power.py:505(_eval_is_finite)
#         9    0.000    0.000    0.003    0.000 power.py:521(_eval_is_prime)
#       764    0.001    0.000    0.001    0.000 power.py:602(as_base_exp)
#        38    0.000    0.000    0.000    0.000 power.py:662(_eval_expand_power_exp)
#        38    0.000    0.000    0.000    0.000 power.py:673(_eval_expand_power_base)
#        57    0.000    0.000    0.000    0.000 power.py:789(_eval_expand_multinomial)
#         1    0.000    0.000    0.000    0.000 printer.py:196(__init__)
#         1    0.000    0.000    0.000    0.000 printer.py:231(doprint)
#         1    0.000    0.000    0.000    0.000 printer.py:235(_print)
#       100    0.001    0.000    0.288    0.003 pyplot.py:3237(scatter)
#       100    0.000    0.000    0.002    0.000 pyplot.py:336(sci)
#       200    0.001    0.000    0.001    0.000 pyplot.py:571(gcf)
#       200    0.000    0.000    0.002    0.000 pyplot.py:910(gca)
#         2    0.000    0.000    0.000    0.000 pythonintegerring.py:23(__init__)
#        21    0.000    0.000    0.000    0.000 pythonintegerring.py:26(to_sympy)
#        21    0.000    0.000    0.000    0.000 pythonintegerring.py:30(from_sympy)
#         2    0.000    0.000    0.000    0.000 pythonintegerring.py:43(from_ZZ_python)
#        58    0.001    0.000    0.006    0.000 radsimp.py:902(fraction)
#      1245    0.014    0.000    0.015    0.000 random.py:277(shuffle)
#        46    0.000    0.000    0.001    0.000 relational.py:286(__new__)
#       200    0.000    0.000    0.000    0.000 scale.py:48(limit_range_for_scale)
#        46    0.000    0.000    0.002    0.000 sets.py:1764(__new__)
#        46    0.000    0.000    0.001    0.000 sets.py:1863(_contains)
#        46    0.000    0.000    0.001    0.000 sets.py:266(contains)
#        46    0.000    0.000    0.000    0.000 sets.py:49(_infimum_key)
#        46    0.000    0.000    0.002    0.000 sets.py:507(__contains__)
#       300    0.001    0.000    0.002    0.000 shape_base.py:113(atleast_3d)
#       101    0.000    0.000    0.001    0.000 shape_base.py:232(hstack)
#       100    0.000    0.000    0.002    0.000 shape_base.py:319(dstack)
#       303    0.001    0.000    0.002    0.000 shape_base.py:9(atleast_1d)
#      2713    0.002    0.000    0.003    0.000 six.py:572(itervalues)
#      1100    0.001    0.000    0.001    0.000 six.py:575(iteritems)
#         1    0.000    0.000    0.000    0.000 str.py:628(_print_Symbol)
#         1    0.000    0.000    0.000    0.000 str.py:732(sstr)
#         1    0.000    0.000    0.000    0.000 symbol.py:137(_hashable_content)
#         1    0.000    0.000    0.000    0.000 symbol.py:141(assumptions0)
#         2    0.000    0.000    0.000    0.000 symbol.py:143(<genexpr>)
#         1    0.000    0.000    0.000    0.000 symbol.py:55(_sanitize)
#         1    0.000    0.000    0.000    0.000 symbol.py:89(__new__)
#        23    0.000    0.000    0.000    0.000 sympify.py:13(__init__)
#      1790    0.001    0.000    0.005    0.000 sympify.py:329(_sympify)
#      4232    0.009    0.000    0.047    0.000 sympify.py:53(sympify)
#       200    0.001    0.000    0.002    0.000 ticker.py:1301(scale_range)
#       200    0.004    0.000    0.006    0.000 ticker.py:1403(bin_boundaries)
#       200    0.001    0.000    0.009    0.000 ticker.py:1445(view_limits)
#       100    0.000    0.000    0.000    0.000 transforms.py:1009(_get_minposx)
#       100    0.000    0.000    0.000    0.000 transforms.py:1013(_get_minposy)
#      1300    0.001    0.000    0.001    0.000 transforms.py:1017(get_points)
#       100    0.000    0.000    0.002    0.000 transforms.py:1065(__init__)
#       100    0.000    0.000    0.001    0.000 transforms.py:1090(get_points)
#       200    0.000    0.000    0.005    0.000 transforms.py:1151(__add__)
#       713    0.001    0.000    0.039    0.000 transforms.py:127(invalidate)
#       100    0.000    0.000    0.005    0.000 transforms.py:1293(transform)
#  3013/713    0.011    0.000    0.038    0.000 transforms.py:138(_invalidate_internal)
#       100    0.000    0.000    0.002    0.000 transforms.py:1579(frozen)
#       800    0.002    0.000    0.008    0.000 transforms.py:162(set_children)
#       100    0.000    0.000    0.000    0.000 transforms.py:1620(_get_is_affine)
#      1800    0.002    0.000    0.015    0.000 transforms.py:1640(__init__)
#       200    0.000    0.000    0.000    0.000 transforms.py:1644(__array__)
#       300    0.000    0.000    0.002    0.000 transforms.py:1661(transform)
#       300    0.000    0.000    0.000    0.000 transforms.py:1687(get_affine)
#       600    0.001    0.000    0.013    0.000 transforms.py:1713(frozen)
#       300    0.001    0.000    0.001    0.000 transforms.py:1741(transform_affine)
#       300    0.001    0.000    0.006    0.000 transforms.py:1769(inverted)
#      1200    0.002    0.000    0.015    0.000 transforms.py:1786(__init__)
#      1200    0.000    0.000    0.000    0.000 transforms.py:1831(get_matrix)
#       100    0.001    0.000    0.002    0.000 transforms.py:1888(rotate)
#       100    0.000    0.000    0.002    0.000 transforms.py:1905(rotate_deg)
#       100    0.000    0.000    0.007    0.000 transforms.py:1925(rotate_deg_around)
#       200    0.001    0.000    0.005    0.000 transforms.py:1935(translate)
#       200    0.001    0.000    0.006    0.000 transforms.py:1950(scale)
#       100    0.000    0.000    0.000    0.000 transforms.py:2016(frozen)
#       100    0.000    0.000    0.000    0.000 transforms.py:2023(get_matrix)
#       200    0.000    0.000    0.000    0.000 transforms.py:2227(get_matrix)
#       400    0.002    0.000    0.009    0.000 transforms.py:2268(__init__)
#   200/100    0.001    0.000    0.018    0.000 transforms.py:2292(frozen)
#  1800/100    0.003    0.000    0.026    0.000 transforms.py:2300(_invalidate_internal)
#   400/300    0.000    0.000    0.001    0.000 transforms.py:2331(_get_is_affine)
#       100    0.000    0.000    0.004    0.000 transforms.py:2346(transform_affine)
#       100    0.000    0.000    0.000    0.000 transforms.py:2350(transform_non_affine)
#   200/100    0.001    0.000    0.003    0.000 transforms.py:2370(get_affine)
#   200/100    0.001    0.000    0.011    0.000 transforms.py:2378(inverted)
#       200    0.001    0.000    0.004    0.000 transforms.py:2394(__init__)
#       200    0.000    0.000    0.001    0.000 transforms.py:2438(get_matrix)
#       400    0.001    0.000    0.010    0.000 transforms.py:2449(composite_transform_factory)
#       100    0.000    0.000    0.002    0.000 transforms.py:2528(__init__)
#       100    0.000    0.000    0.000    0.000 transforms.py:2545(get_matrix)
#       200    0.001    0.000    0.004    0.000 transforms.py:2604(get_matrix)
#       600    0.003    0.000    0.004    0.000 transforms.py:2725(nonsingular)
#       300    0.000    0.000    0.000    0.000 transforms.py:281(__array__)
#       400    0.001    0.000    0.001    0.000 transforms.py:366(_get_intervalx)
#       400    0.001    0.000    0.001    0.000 transforms.py:373(_get_intervaly)
#       100    0.001    0.000    0.002    0.000 transforms.py:401(_get_bounds)
#       100    0.001    0.000    0.008    0.000 transforms.py:518(transformed)
#       100    0.001    0.000    0.020    0.000 transforms.py:528(inverse_transformed)
#       200    0.000    0.000    0.000    0.000 transforms.py:722(union)
#       400    0.002    0.000    0.007    0.000 transforms.py:780(__init__)
#       100    0.000    0.000    0.003    0.000 transforms.py:811(unit)
#       100    0.000    0.000    0.002    0.000 transforms.py:827(from_bounds)
#       200    0.001    0.000    0.005    0.000 transforms.py:837(from_extents)
#      2700    0.004    0.000    0.019    0.000 transforms.py:86(__init__)
#       100    0.000    0.000    0.001    0.000 transforms.py:897(update_from_path)
#       100    0.000    0.000    0.004    0.000 transforms.py:933(update_from_data_xy)
#       100    0.000    0.000    0.031    0.000 transforms.py:987(_set_intervalx)
#       100    0.000    0.000    0.002    0.000 transforms.py:992(_set_intervaly)
#       300    0.002    0.000    0.002    0.000 twodim_base.py:192(eye)
#       101    0.001    0.000    0.001    0.000 twodim_base.py:244(diag)
#  1400/900    0.005    0.000    0.009    0.000 units.py:125(get_converter)
#      1500    0.002    0.000    0.006    0.000 weakref.py:105(__setitem__)
#      5013    0.008    0.000    0.020    0.000 weakref.py:183(itervalues)
#      1500    0.001    0.000    0.002    0.000 weakref.py:277(__new__)
#      1500    0.002    0.000    0.002    0.000 weakref.py:282(__init__)
#      2700    0.010    0.000    0.014    0.000 weakref.py:47(__init__)
#       800    0.001    0.000    0.001    0.000 weakref.py:55(remove)
#      2713    0.001    0.000    0.001    0.000 weakref.py:68(_commit_removals)
#      4019    0.003    0.000    0.003    0.000 {_bisect.bisect}
#       100    0.000    0.000    0.000    0.000 {_functools.reduce}
#      1701    0.000    0.000    0.000    0.000 {abs}
# 3463/3431    0.001    0.000    0.005    0.000 {all}
#     98/60    0.000    0.000    0.001    0.000 {any}
#      6602    0.002    0.000    0.002    0.000 {built-in method __new__ of type object at 0x100161d60}
#       200    0.000    0.000    0.000    0.000 {callable}
#         9    0.000    0.000    0.000    0.000 {compile}
#   602/601    0.000    0.000    0.000    0.000 {divmod}
#     12311    0.007    0.000    0.007    0.000 {getattr}
#      6687    0.004    0.000    0.004    0.000 {hasattr}
# 4342/3964    0.001    0.000    0.001    0.000 {hash}
#      1500    0.000    0.000    0.000    0.000 {id}
#     52902    0.014    0.000    0.014    0.000 {isinstance}
#      1005    0.001    0.000    0.001    0.000 {issubclass}
#      5614    0.001    0.000    0.001    0.000 {iter}
#     27333    0.003    0.000    0.003    0.000 {len}
#       655    0.001    0.000    0.005    0.000 {map}
#      2100    0.001    0.000    0.001    0.000 {math.frexp}
#      2121    0.001    0.000    0.001    0.000 {math.ldexp}
#       200    0.000    0.000    0.000    0.000 {math.log10}
#       300    0.001    0.000    0.001    0.000 {matplotlib._path.affine_transform}
#       100    0.006    0.000    0.008    0.000 {matplotlib._path.get_path_collection_extents}
#       100    0.001    0.000    0.001    0.000 {matplotlib._path.update_path_extents}
#      5117    0.002    0.000    0.002    0.000 {max}
#       100    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#      2733    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#       802    0.001    0.000    0.005    0.000 {method 'all' of 'numpy.ndarray' objects}
#      7057    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#       302    0.002    0.000    0.010    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       118    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#      1000    0.001    0.000    0.001    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#      1656    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       100    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#     10342    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'groups' of '_sre.SRE_Match' objects}
#       438    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#       474    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#      5087    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#      1100    0.000    0.000    0.000    0.000 {method 'iteritems' of 'dict' objects}
#      2713    0.003    0.000    0.003    0.000 {method 'itervalues' of 'dict' objects}
#        51    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       800    0.000    0.000    0.000    0.000 {method 'lower' of 'unicode' objects}
#         1    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#       200    0.000    0.000    0.001    0.000 {method 'max' of 'numpy.ndarray' objects}
#       200    0.000    0.000    0.001    0.000 {method 'min' of 'numpy.ndarray' objects}
#       201    0.001    0.000    0.002    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#      1563    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        46    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       100    0.001    0.000    0.001    0.000 {method 'rand' of 'mtrand.RandomState' objects}
#     13689    0.001    0.000    0.001    0.000 {method 'random' of '_random.Random' objects}
#       801    0.001    0.000    0.001    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1002    0.005    0.000    0.005    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      2713    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#       300    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      1488    0.001    0.000    0.002    0.000 {method 'setdefault' of 'dict' objects}
#       500    0.001    0.000    0.020    0.000 {method 'sort' of 'list' objects}
#       200    0.001    0.000    0.001    0.000 {method 'take' of 'numpy.ndarray' objects}
#      3403    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#      1043    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#       200    0.001    0.000    0.006    0.000 {method 'view' of 'numpy.generic' objects}
#       100    0.000    0.000    0.003    0.000 {method 'view' of 'numpy.ndarray' objects}
#       224    0.000    0.000    0.000    0.000 {min}
#       200    0.001    0.000    0.001    0.000 {numpy.core.multiarray.arange}
#      5207    0.008    0.000    0.008    0.000 {numpy.core.multiarray.array}
#       201    0.001    0.000    0.001    0.000 {numpy.core.multiarray.concatenate}
#       101    0.000    0.000    0.000    0.000 {numpy.core.multiarray.copyto}
#       900    0.003    0.000    0.003    0.000 {numpy.core.multiarray.dot}
#       301    0.000    0.000    0.000    0.000 {numpy.core.multiarray.empty}
#       602    0.001    0.000    0.001    0.000 {numpy.core.multiarray.zeros}
#         1    0.000    0.000    0.000    0.000 {range}
#      2146    0.001    0.000    0.001    0.000 {round}
#        50    0.000    0.000    0.000    0.000 {sorted}
#      1524    0.001    0.000    0.001    0.000 {zip}
